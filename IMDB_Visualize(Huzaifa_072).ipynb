# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('imdb (1000 movies) in june 2022.csv')

# %% [markdown]
# 1. LOC

# %%
data.loc[data["Year"]=="-2002"]
# Out:
#     ranking of movie\r\n                         movie name\r\n   Year  \
# 10                    11  The Lord of the Rings: The Two Towers  -2002
# 22                    23                            City of God  -2002
# 42                    43                            The Pianist  -2002
# 257                  258                    Catch Me If You Can  -2002
# 379                  380                       Infernal Affairs  -2002
# 513                  514                                   Hero  -2002
# 514                  515                            Talk to Her  -2002
# 516                  517                    The Bourne Identity  -2002
# 661                  662                           Lilya 4-Ever  -2002
# 804                  805                  The Magdalene Sisters  -2002
# 808                  809                             In America  -2002
# 810                  811                            Adaptation.  -2002
# ...

# %%
2. ILOC

# %%
data.iloc[0:4,2:5]
# Out:
#     Year certificate  runtime
# 0  -1994          15  142 min
# 1  -1972           X  175 min
# 2  -2008         12A  152 min
# 3  -2003         12A  201 min

# %%
3. SUM()

# %%
data4 = [[10, 18, 11], [13, 15, 8], [9, 20, 3]]

df = pd.DataFrame(data4)

print(df.sum())
# Out:
# 0    32
# 1    53
# 2    22
# dtype: int64

# %%
4. INFO()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ranking of movie
#    1000 non-null   object
#  1   movie name
#          1000 non-null   object
#  2   Year                 1000 non-null   object
#  3   certificate          995 non-null    object
#  4   runtime              1000 non-null   object
#  5   genre                1000 non-null   object
#  6   RATING               1000 non-null   float64
#  7   metascore            837 non-null    float64
#  8   DETAIL ABOUT MOVIE
#   1000 non-null   object
#  9   DIRECTOR
#            1000 non-null   object
#  10  ACTOR 1
#              1000 non-null   object
#  11  ACTOR 2
#              1000 non-null   object
#  12  ACTOR 3              1000 non-null   object
#  13  ACTOR 4              1000 non-null   object
#  14  votes                1000 non-null   object
# ...

# %%
5. DESCRIBE()

# %%
data.describe()
# Out:
#             RATING   metascore
# count  1000.000000  837.000000
# mean      7.960200   78.629630
# std       0.276717   12.049598
# min       7.600000   28.000000
# 25%       7.700000   71.000000
# 50%       7.900000   80.000000
# 75%       8.100000   88.000000
# max       9.300000  100.000000

# %%
6. GROUPBY()

# %%
data.groupby('Year')

# %%
7. ISNULL()

# %%
data.isnull()
# Out:
#      ranking of movie\r\n  movie name\r\n   Year  certificate  runtime  genre  \
# 0                   False           False  False        False    False  False
# 1                   False           False  False        False    False  False
# 2                   False           False  False        False    False  False
# 3                   False           False  False        False    False  False
# 4                   False           False  False        False    False  False
# ..                    ...             ...    ...          ...      ...    ...
# 995                 False           False  False        False    False  False
# 996                 False           False  False        False    False  False
# 997                 False           False  False        False    False  False
# 998                 False           False  False        False    False  False
# 999                 False           False  False        False    False  False
#
# ...

# %%
8. ISNULL().SUM()

# %%
data.isnull().sum()
# Out:
# index                   0
# id                      0
# title                   0
# type                    0
# description             5
# release_year            0
# age_certification    2285
# runtime                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes             16
# dtype: int64

# %%
9. ISNA()

# %%
data.isna()
# Out:
#      ranking of movie\r\n  movie name\r\n   Year  certificate  runtime  genre  \
# 0                   False           False  False        False    False  False
# 1                   False           False  False        False    False  False
# 2                   False           False  False        False    False  False
# 3                   False           False  False        False    False  False
# 4                   False           False  False        False    False  False
# ..                    ...             ...    ...          ...      ...    ...
# 995                 False           False  False        False    False  False
# 996                 False           False  False        False    False  False
# 997                 False           False  False        False    False  False
# 998                 False           False  False        False    False  False
# 999                 False           False  False        False    False  False
#
# ...

# %%
10. MEAN

# %%
data1 = [[1, 1, 2], [6, 4, 2], [4, 2, 1], [4, 2, 3]]

df = pd.DataFrame(data1)

print(df.mean())
# Out:
# 0    3.75
# 1    2.25
# 2    2.00
# dtype: float64

# %%
11. MA()

# %%
window_size = 3
moving_avg = data['Year'].rolling(window=window_size).mean()

# %%
12. MEDIAN

# %%
data2 = [[1, 1, 2], [6, 4, 2], [4, 2, 1], [4, 2, 3]]

df = pd.DataFrame(data2)

print(df.median())
# Out:
# 0    4.0
# 1    2.0
# 2    2.0
# dtype: float64

# %%
13. AGG

# %%
data3 = {
  "x": [50, 40, 30],
  "y": [300, 1112, 42]
}

df = pd.DataFrame(data3)

x = df.agg(["sum"])

print(x)
# Out:
#        x     y
# sum  120  1454

# %%
14. DTYPE

# %%
data.dtypes
# Out:
# ranking of movie\r\n     object
# movie name\r\n           object
# Year                     object
# certificate              object
# runtime                  object
# genre                    object
# RATING                  float64
# metascore               float64
# DETAIL ABOUT MOVIE\n     object
# DIRECTOR\r\n             object
# ACTOR 1\n                object
# ACTOR 2\n                object
# ACTOR 3                  object
# ACTOR 4                  object
# votes                    object
# GROSS COLLECTION\r\n     object
# dtype: object
